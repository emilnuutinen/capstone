# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('sensor_data.csv', names=["ecg", "ppg1 Ir",
                                             "ppg1 Red", "ppg1 Green", "ppg2 Ir", "ppg2 Red", "ppg2 Green"],
                                              usecols=[1,3,4,5,7,8,9,])

data.head()
# Out:
#     ecg  ppg1 Ir  ppg1 Red  ppg1 Green  ppg2 Ir  ppg2 Red  ppg2 Green
# 0     0     7017        12         819   144441         4        7399
# 1  4095     7012         5         797   144442         0        7438
# 2     0     7017         8         788   144434         0        7442
# 3  4095     7009         0         797   144468         0        7463
# 4     0     7025         0         835   144493         0        7462

# %%
data.plot(grid=True)
# Out:
# <AxesSubplot:>

# %%
data['ppg1 Ir'].plot(grid=True)
# Out:
# <AxesSubplot:>
